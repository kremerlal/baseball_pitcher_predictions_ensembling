# %% [markdown]
# # Sabermetrics

# %% [markdown]
# Class project to learn about ensembling and combining models to find a good baseball player within budget. The goal is to predict IP and RA9 for the 2013 season, Moneyball-style...although I never got around to watching the movie. Can't take credit for the starter code, can take credit for about half of the improvements.

# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib as mpl
import seaborn as sns
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# # Read in the data

# %% [markdown]
# The data set here is a data set of pitcher information combined with predictions on the IP (or _innings pitched_) and RA9 (or _runs allowed per 9 innings_). These predictions come from four different groups as stated in the case.
#
# `train_saber.csv` is predictions for the 2012 season, which has already happened, so we also have the realizations for IP and RA9 for the 2012 season. We are trying to predict the 2013 season. `test_saber.csv` has all of the currently available information that we would have in making his hiring decisions, but it does not have any data from the 2013 season.

# %%
train_df = pd.read_csv("train_saber.csv")

# %%
display(train_df.head())
# Out:
#               NAME  IP_fans  RA9_fans  IP_marcel  RA9_marcel  IP_rotochamp  \
# 0       Aaron Crow      127  4.187402         56    4.132736           150
# 1     Aaron Harang      164  4.602863        156    4.701261           180
# 2  Adam Wainwright      196  3.443947         83    3.203417           175
# 3        Alex Cobb      103  4.099937         86    4.176469           110
# 4     Alexi Ogando      175  3.826608        130    3.826608           185
#
#    RA9_rotochamp  IP_zips  RA9_zips   playerID  ...  bats  throws      debut  \
# 0       3.607945     67.3  4.963657   crowaa01  ...     R       R  3/31/2011
# 1       4.646595    133.7  4.712194  haranaa01  ...     R       R  5/25/2002
# 2       3.771942    173.3  3.411148  wainwad01  ...     R       R  9/11/2005
# 3       4.209269    122.0  4.351400   cobbal01  ...     R       R   5/1/2011
# 4       4.045271    150.0  4.067137  ogandal01  ...     R       R  6/15/2010
#
#    finalGame   retroID    bbrefID  deathDate   birthDate          IP       RA9
# 0  9/28/2014  crowa001   crowaa01        NaN  1986-11-10   64.666667  3.757732
# 1  9/27/2014  haraa001  haranaa01        NaN  1978-05-09  179.666667  4.257885
# 2  9/22/2014  waina001  wainwad01        NaN  1981-08-30  198.666667  4.348993
# 3  9/28/2014  cobba001   cobbal01        NaN  1987-10-07  136.333333  4.422983
# 4   6/3/2014  ogana001  ogandal01        NaN  1983-10-05   66.000000  3.545455
#
# [5 rows x 66 columns]

# %%
test_df = pd.read_csv("test_saber.csv")

# %%
display(test_df.head())
# Out:
#               NAME  IP_fans  RA9_fans  IP_marcel  RA9_marcel  IP_rotochamp  \
# 0       Aaron Crow       66  3.538949       63.7    3.843843            60
# 1  Adam Wainwright      215  3.462725      159.3    3.996290           195
# 2     Addison Reed       61  3.789397       53.3    4.595189            60
# 3  Al Alburquerque       62  2.929161       36.0    3.538949            55
# 4        Alex Cobb      164  4.159626      133.7    4.181404           140
#
#    RA9_rotochamp  IP_zips  RA9_zips   playerID  ...  bats  throws       debut  \
# 0       3.593394     64.0  4.137848   crowaa01  ...     R       R  2011-03-31
# 1       3.462725    173.7  3.724063  wainwad01  ...     R       R  2005-09-11
# 2       4.246739     66.7  4.257628   reedad01  ...     L       R  2011-09-04
# 3       3.027162     34.7  4.235849  albural01  ...     R       R  2011-04-15
# 4       3.920066    149.3  4.529854   cobbal01  ...     R       R  2011-05-01
#
#   finalGame   retroID    bbrefID  deathDate   birthDate  IP  RA9
# 0       NaN  crowa001   crowaa01        NaN  1986-11-10 NaN  NaN
# 1       NaN  waina001  wainwad01        NaN  1981-08-30 NaN  NaN
# 2       NaN  reeda001   reedad01        NaN  1988-12-27 NaN  NaN
# 3       NaN  albua001  albural01        NaN  1986-06-10 NaN  NaN
# 4       NaN  cobba001   cobbal01        NaN  1987-10-07 NaN  NaN
#
# [5 rows x 66 columns]

# %%
def summarize_dataframe(df):
    """Summarize a dataframe, and report missing values."""
    missing_values = pd.concat([pd.DataFrame(df.columns, columns=['Variable Name']), 
                      pd.DataFrame(df.dtypes.values.reshape([-1,1]), columns=['Data Type']),
                      pd.DataFrame(df.isnull().sum().values, columns=['Missing Values']), 
                      pd.DataFrame([df[name].nunique() for name in df.columns], columns=['Unique Values'])], 
                     axis=1).set_index('Variable Name')
    with pd.option_context("display.max_rows", 1000):
        display(pd.concat([missing_values, df.describe(include='all').transpose()], axis=1).fillna(""))

# %%
summarize_dataframe(train_df)
# Out:
#               Data Type  Missing Values  Unique Values  count unique  \
# NAME             object               0            182  182.0    182
# IP_fans           int64               0            107  182.0
# RA9_fans        float64               0            120  182.0
# IP_marcel         int64               0            100  182.0
# RA9_marcel      float64               0            115  182.0
# IP_rotochamp      int64               0             28  182.0
# RA9_rotochamp   float64               0            107  182.0
# IP_zips         float64               0            148  182.0
# RA9_zips        float64               0            129  182.0
# playerID         object               0            182  182.0    182
# yearID            int64               0              1  182.0
# stint             int64               0              1  182.0
# teamID           object               0             30  182.0     30
# lgID             object               0              2  182.0      2
# W                 int64               0             22  182.0
# L                 int64               0             18  182.0
# G                 int64               0             58  182.0
# GS                int64               0             34  182.0
# CG                int64               0              7  182.0
# SHO               int64               0              5  182.0
# SV                int64               0             24  182.0
# IPouts            int64               0            156  182.0
# H                 int64               0            124  182.0
# ER                int64               0             86  182.0
# HR                int64               0             35  182.0
# BB                int64               0             75  182.0
# SO                int64               0            124  182.0
# BAOpp           float64               0             99  182.0
# ERA             float64               0            142  182.0
# IBB               int64               0             11  182.0
# WP                int64               0             16  182.0
# HBP               int64               0             15  182.0
# BK                int64               0              5  182.0
# BFP               int64               0            157  182.0
# GF                int64               0             38  182.0
# R                 int64               0             92  182.0
# SH                int64               0             18  182.0
# SF                int64               0             12  182.0
# GIDP            float64             182              0    0.0
# birthYear         int64               0             20  182.0
# birthMonth        int64               0             12  182.0
# birthDay          int64               0             31  182.0
# birthCountry     object               0             13  182.0     13
# birthState       object               6             60  176.0     60
# birthCity        object               0            159  182.0    159
# deathYear       float64             182              0    0.0
# deathMonth      float64             182              0    0.0
# deathDay        float64             182              0    0.0
# deathCountry    float64             182              0    0.0
# deathState      float64             182              0    0.0
# deathCity       float64             182              0    0.0
# nameFirst        object               0            129  182.0    129
# nameLast         object               0            177  182.0    177
# nameGiven        object               0            181  182.0    181
# weight            int64               0             23  182.0
# height            int64               0             13  182.0
# bats             object               0              3  182.0      3
# throws           object               0              2  182.0      2
# debut            object               0            175  182.0    175
# finalGame        object               0             76  182.0     76
# retroID          object               0            182  182.0    182
# bbrefID          object               0            182  182.0    182
# deathDate       float64             182              0    0.0
# birthDate        object               0            178  182.0    178
# IP              float64               0            156  182.0
# RA9             float64               0            178  182.0
#
#                           top freq         mean         std       min  \
# NAME               Aaron Crow    1
# IP_fans                              141.467033   58.286836      48.0
# RA9_fans                               3.947053    0.647344  2.536494
# IP_marcel                            119.445055   51.185879      37.0
# RA9_marcel                             4.058247    0.534799  2.897289
# IP_rotochamp                         136.236264   58.484396      30.0
# RA9_rotochamp                          4.008146    0.740808  1.825839
# IP_zips                               128.71978    53.35577      41.7
# RA9_zips                               4.192568    0.729662  2.405296
# playerID             crowaa01    1
# yearID                                   2012.0         0.0    2012.0
# stint                                       1.0         0.0       1.0
# teamID                    ATL   11
# lgID                       NL  101
# W                                           7.0    5.207305       0.0
# L                                      6.467033    4.292678       0.0
# G                                     34.516484   20.160057       1.0
# GS                                    15.576923   13.512103       0.0
# CG                                     0.538462    1.049153       0.0
# SHO                                     0.28022    0.675984       0.0
# SV                                     3.917582    9.950086       0.0
# IPouts                               339.368132   205.02853       6.0
# H                                    107.763736   67.288726       4.0
# ER                                    48.994505   31.334499       2.0
# HR                                     12.71978    9.011567       0.0
# BB                                     36.06044   22.044948       1.0
# SO                                    96.010989   58.278716       2.0
# BAOpp                                  0.250725    0.041542     0.126
# ERA                                    4.045165    1.458587      1.01
# IBB                                    2.126374    2.030286       0.0
# WP                                     3.527473    3.144198       0.0
# HBP                                    3.752747     3.32899       0.0
# BK                                     0.373626    0.715238       0.0
# BFP                                  476.120879  284.064534      12.0
# GF                                     8.642857   16.148446       0.0
# R                                     52.835165   33.688618       2.0
# SH                                      3.82967     3.73258       0.0
# SF                                     2.956044    2.426429       0.0
# GIDP
# birthYear                           1983.351648    3.833189    1969.0
# birthMonth                             6.554945     3.50292       1.0
# birthDay                              15.747253    9.327786       1.0
# birthCountry              USA  139
# birthState                 CA   32
# birthCity           San Diego    6
# deathYear
# deathMonth
# deathDay
# deathCountry
# deathState
# deathCity
# nameFirst                Matt    6
# nameLast               Garcia    2
# nameGiven      Joshua Michael    2
# weight                               216.593407    21.13988     170.0
# height                                 74.82967    2.305075      67.0
# bats                        R  134
# throws                      R  136
# debut               3/31/2011    2
# finalGame           9/28/2014   25
# retroID              crowa001    1
# bbrefID              crowaa01    1
# deathDate
# birthDate          1981-12-20    2
# IP                                   113.122711   68.342843       2.0
# RA9                                    4.355695    1.548556  1.005319
#
#                      25%        50%         75%         max
# NAME
# IP_fans             69.0      159.5       191.5       242.0
# RA9_fans         3.44668   3.974206    4.479864    5.444716
# IP_marcel           64.0      126.5       167.0       208.0
# RA9_marcel      3.673544   4.001538    4.468931    5.499382
# IP_rotochamp        60.0      155.0       190.0       220.0
# RA9_rotochamp   3.545079   4.045271    4.608329    5.783644
# IP_zips           70.325      140.0     173.225       237.3
# RA9_zips        3.698143    4.14367    4.695794    6.341236
# playerID
# yearID            2012.0     2012.0      2012.0      2012.0
# stint                1.0        1.0         1.0         1.0
# teamID
# lgID
# W                    3.0        5.0        11.0        21.0
# L                    3.0        6.0        10.0        17.0
# G                   21.0       31.0        44.0        77.0
# GS                   0.0       16.0       30.75        34.0
# CG                   0.0        0.0         1.0         6.0
# SHO                  0.0        0.0         0.0         5.0
# SV                   0.0        0.0         1.0        42.0
# IPouts             176.0      295.0      538.75       715.0
# H                   49.0       95.0       172.5       228.0
# ER                  20.0       42.0        78.0       118.0
# HR                   5.0       11.0        20.0        39.0
# BB                 18.25       32.5        51.0       105.0
# SO                 48.75       88.0      139.25       239.0
# BAOpp              0.229       0.25        0.27       0.412
# ERA                3.085      3.795        4.67       10.29
# IBB                  1.0        2.0         3.0        10.0
# WP                   1.0        3.0         5.0        17.0
# HBP                  1.0        3.0         5.0        14.0
# BK                   0.0        0.0         1.0         4.0
# BFP                244.0      425.5      780.25       956.0
# GF                   0.0        0.0        9.75        67.0
# R                   23.0       47.0        82.0       127.0
# SH                   1.0        3.0         5.0        19.0
# SF                   1.0        3.0         4.0        11.0
# GIDP
# birthYear         1982.0     1984.0      1986.0      1991.0
# birthMonth           3.0        7.0         9.0        12.0
# birthDay            7.25       15.0        24.0        31.0
# birthCountry
# birthState
# birthCity
# deathYear
# deathMonth
# deathDay
# deathCountry
# deathState
# deathCity
# nameFirst
# nameLast
# nameGiven
# weight             205.0      215.0       230.0       285.0
# height              73.0       75.0        76.0        81.0
# bats
# throws
# debut
# finalGame
# retroID
# bbrefID
# deathDate
# birthDate
# IP             58.666667  98.333333  179.583333  238.333333
# RA9             3.390623   4.176101    5.168425   12.857143

# %%
summarize_dataframe(test_df)
# Out:
#               Data Type  Missing Values  Unique Values  count unique  \
# NAME             object               0            191  191.0    191
# IP_fans           int64               0             99  191.0
# RA9_fans        float64               0            120  191.0
# IP_marcel       float64               0            150  191.0
# RA9_marcel      float64               0            117  191.0
# IP_rotochamp      int64               0             33  191.0
# RA9_rotochamp   float64               0            116  191.0
# IP_zips         float64               0            161  191.0
# RA9_zips        float64               0            139  191.0
# playerID         object               0            191  191.0    191
# yearID            int64               0              1  191.0
# stint             int64               0              1  191.0
# teamID           object               0             30  191.0     30
# lgID             object               0              2  191.0      2
# W               float64             191              0    0.0
# L               float64             191              0    0.0
# G               float64             191              0    0.0
# GS              float64             191              0    0.0
# CG              float64             191              0    0.0
# SHO             float64             191              0    0.0
# SV              float64             191              0    0.0
# IPouts          float64             191              0    0.0
# H               float64             191              0    0.0
# ER              float64             191              0    0.0
# HR              float64             191              0    0.0
# BB              float64             191              0    0.0
# SO              float64             191              0    0.0
# BAOpp           float64             191              0    0.0
# ERA             float64             191              0    0.0
# IBB             float64             191              0    0.0
# WP              float64             191              0    0.0
# HBP             float64             191              0    0.0
# BK              float64             191              0    0.0
# BFP             float64             191              0    0.0
# GF              float64             191              0    0.0
# R               float64             191              0    0.0
# SH              float64             191              0    0.0
# SF              float64             191              0    0.0
# GIDP            float64             191              0    0.0
# birthYear         int64               0             21  191.0
# birthMonth        int64               0             12  191.0
# birthDay          int64               0             31  191.0
# birthCountry     object               0             15  191.0     15
# birthState       object               5             66  186.0     66
# birthCity        object               0            161  191.0    161
# deathYear       float64             191              0    0.0
# deathMonth      float64             191              0    0.0
# deathDay        float64             191              0    0.0
# deathCountry    float64             191              0    0.0
# deathState      float64             191              0    0.0
# deathCity       float64             191              0    0.0
# nameFirst        object               0            142  191.0    142
# nameLast         object               0            185  191.0    185
# nameGiven        object               0            191  191.0    191
# weight            int64               0             22  191.0
# height            int64               0             11  191.0
# bats             object               0              3  191.0      3
# throws           object               0              2  191.0      2
# debut            object               0            182  191.0    182
# finalGame       float64             191              0    0.0
# retroID          object               0            191  191.0    191
# bbrefID          object               0            191  191.0    191
# deathDate       float64             191              0    0.0
# birthDate        object               0            186  191.0    186
# IP              float64             191              0    0.0
# RA9             float64             191              0    0.0
#
#                        top freq        mean        std       min       25%  \
# NAME            Aaron Crow    1
# IP_fans                          139.125654  57.950931      51.0      70.0
# RA9_fans                           3.894982    0.63256  2.450041  3.440947
# IP_marcel                        116.719372  51.228593      34.0      65.0
# RA9_marcel                         4.080666   0.514831  2.754935  3.702285
# IP_rotochamp                     130.026178  59.616091      25.0      60.0
# RA9_rotochamp                      3.979244    0.69107  1.676917   3.52806
# IP_zips                          128.963351  53.051221      23.0     68.65
# RA9_zips                            4.25415   0.754846  1.709584  3.734952
# playerID          crowaa01    1
# yearID                               2013.0        0.0    2013.0    2013.0
# stint                                   1.0        0.0       1.0       1.0
# teamID                 TOR   10
# lgID                    AL  104
# W
# L
# G
# GS
# CG
# SHO
# SV
# IPouts
# H
# ER
# HR
# BB
# SO
# BAOpp
# ERA
# IBB
# WP
# HBP
# BK
# BFP
# GF
# R
# SH
# SF
# GIDP
# birthYear                        1983.95288   4.210623    1969.0    1982.0
# birthMonth                         6.816754   3.356523       1.0       4.0
# birthDay                          16.073298   8.955144       1.0       8.0
# birthCountry           USA  142
# birthState              CA   31
# birthCity          Houston    4
# deathYear
# deathMonth
# deathDay
# deathCountry
# deathState
# deathCity
# nameFirst            Chris    5
# nameLast           Holland    2
# nameGiven      Aaron James    1
# weight                           215.602094  19.358904     170.0     205.0
# height                            74.816754   2.140569      70.0      74.0
# bats                     R  137
# throws                   R  139
# debut           2010-08-02    2
# finalGame
# retroID           crowa001    1
# bbrefID           crowaa01    1
# deathDate
# birthDate       1986-10-09    2
# IP
# RA9
#
#                     50%       75%       max
# NAME
# IP_fans           158.0     191.0     233.0
# RA9_fans       3.952734  4.371963  5.128753
# IP_marcel         120.0     165.2     204.3
# RA9_marcel     4.105181  4.453631  5.477204
# IP_rotochamp      150.0     185.0     220.0
# RA9_rotochamp  4.028957  4.475409  5.488093
# IP_zips           141.3    169.85     228.3
# RA9_zips       4.235849  4.769414  6.184994
# playerID
# yearID           2013.0    2013.0    2013.0
# stint               1.0       1.0       1.0
# teamID
# lgID
# W
# L
# G
# GS
# CG
# SHO
# SV
# IPouts
# H
# ER
# HR
# BB
# SO
# BAOpp
# ERA
# IBB
# WP
# HBP
# BK
# BFP
# GF
# R
# SH
# SF
# GIDP
# birthYear        1985.0    1987.0    1991.0
# birthMonth          7.0      10.0      12.0
# birthDay           16.0      24.0      31.0
# birthCountry
# birthState
# birthCity
# deathYear
# deathMonth
# deathDay
# deathCountry
# deathState
# deathCity
# nameFirst
# nameLast
# nameGiven
# weight            215.0     225.0     295.0
# height             75.0      76.0      80.0
# bats
# throws
# debut
# finalGame
# retroID
# bbrefID
# deathDate
# birthDate
# IP
# RA9

# %% [markdown]
# ## Model building

# %%
def accuracy(y_true, y_pred):
    """Function that returns a table showing RMSE and MAE."""
    acc_df = pd.DataFrame(data = {"RMSE": [mean_squared_error(y_true, y_pred)**(1/2)],
                                  "MAE": [mean_absolute_error(y_true, y_pred)],
                                  "R^2": [r2_score(y_true, y_pred)]})
    display(acc_df.style.hide_index())

# %% [markdown]
# ## Building Ensembles

# %%
import statsmodels.formula.api as smf

# %%
lm_RA9 = smf.ols(formula='RA9 ~ RA9_fans+RA9_marcel+RA9_rotochamp+RA9_zips', data=train_df).fit()
lm_RA9.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    RA9   R-squared:                       0.149
# Model:                            OLS   Adj. R-squared:                  0.129
# Method:                 Least Squares   F-statistic:                     7.731
# Date:                Fri, 24 Dec 2021   Prob (F-statistic):           9.17e-06
# Time:                        19:22:54   Log-Likelihood:                -322.68
# No. Observations:                 182   AIC:                             655.4
# Df Residuals:                     177   BIC:                             671.4
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         1.0520      0.845      1.245      0.215      -0.615       2.719
# RA9_fans          0.4409      0.432      1.020      0.309      -0.412       1.294
# RA9_marcel       -0.0496      0.420     -0.118      0.906      -0.879       0.780
# RA9_rotochamp     0.6758      0.309      2.186      0.030       0.066       1.286
# RA9_zips         -0.2252      0.385     -0.585      0.559      -0.985       0.535
# ==============================================================================
# Omnibus:                       76.887   Durbin-Watson:                   1.729
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              308.669
# Skew:                           1.621   Prob(JB):                     9.40e-68
# Kurtosis:                       8.494   Cond. No.                         69.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
RA9_pred_2012 = train_df["RA9_fans"]*0.4409 \
+train_df["RA9_marcel"]*-0.0496 \
+train_df["RA9_rotochamp"]*0.6758 \
+train_df["RA9_zips"]*-0.22528 + 1.0520

# %%
accuracy(train_df["RA9"], RA9_pred_2012)
# Out:
# <style type="text/css">
# </style>
# <table id="T_44dd2_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >RMSE</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >R^2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_44dd2_row0_col0" class="data row0 col0" >1.424835</td>
#       <td id="T_44dd2_row0_col1" class="data row0 col1" >1.021027</td>
#       <td id="T_44dd2_row0_col2" class="data row0 col2" >0.148729</td>
#     </tr>
#   </tbody>
# </table>

# %%
lm_IP = smf.ols(formula='IP ~ IP_fans+IP_marcel+IP_rotochamp+IP_zips', data=train_df).fit()
lm_IP.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     IP   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     39.31
# Date:                Fri, 24 Dec 2021   Prob (F-statistic):           1.57e-23
# Time:                        19:25:28   Log-Likelihood:                -968.76
# No. Observations:                 182   AIC:                             1948.
# Df Residuals:                     177   BIC:                             1964.
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -2.2621      9.983     -0.227      0.821     -21.964      17.439
# IP_fans          0.5642      0.258      2.189      0.030       0.056       1.073
# IP_marcel        0.0590      0.188      0.314      0.754      -0.312       0.430
# IP_rotochamp     0.0291      0.234      0.125      0.901      -0.433       0.491
# IP_zips          0.1908      0.195      0.979      0.329      -0.194       0.575
# ==============================================================================
# Omnibus:                       13.514   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.680
# Skew:                          -0.693   Prob(JB):                     0.000649
# Kurtosis:                       3.132   Cond. No.                         762.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
IP_pred_2012 = train_df["IP_fans"]*0.5642 \
+train_df["IP_marcel"]*0.0590 \
+train_df["IP_rotochamp"]*0.0291 \
+train_df["IP_zips"]*0.1908 -2.2621

# %%
accuracy(train_df["IP"], IP_pred_2012)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e848f_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >RMSE</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >R^2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e848f_row0_col0" class="data row0 col0" >49.597127</td>
#       <td id="T_e848f_row0_col1" class="data row0 col1" >38.914154</td>
#       <td id="T_e848f_row0_col2" class="data row0 col2" >0.470434</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Pick your Pitchers

# %% [markdown]
# After you build your predictions, use them, along with the other data in the case, to choose the pitchers you will sign. You will need to get the predicted IP and RA9 of all of the free agent pitchers in exhibit 4. Below is an easy way to find the indices of all of the pitchers.

# %%
IP_pred_2013 = test_df["IP_fans"]*0.5642 \
+test_df["IP_marcel"]*0.0590 \
+test_df["IP_rotochamp"]*0.0291 \
+test_df["IP_zips"]*0.1908 -2.2621

# %%
print(IP_pred_2013)
# Out:
# 0       52.69060
# 1      167.25606
# 2       49.77116
# 3       43.06356
# 4      130.71544
#          ...
# 186    166.90340
# 187    169.74320
# 188     93.87240
# 189    130.46796
# 190    171.10364
# Length: 191, dtype: float64

# %%
RA9_pred_2013 = test_df["RA9_fans"]*0.4409 \
+test_df["RA9_marcel"]*-0.0496 \
+test_df["RA9_rotochamp"]*0.6758 \
+test_df["RA9_zips"]*-0.22528 + 1.0520

# %%
free_agents = ["Andy Pettitte",
               "Bartolo Colon",
               "Brandon McCarthy",
               "Francisco Liriano",
               "Hiroki Kuroda",
               "Joe Blanton",
               "Joe Saunders",
               "Kevin Correia",
               "Paul Maholm",
               "Ryan Dempster",
               "Shaun Marcum",
               "Anibal Sanchez",
               "Brett Myers",
               "Hisashi Iwakuma",
               "Jeremy Guthrie",
               "Zack Greinke"]

# %%
test_df.loc[test_df["NAME"].isin(free_agents)]
# Out:
#                   NAME  IP_fans  RA9_fans  IP_marcel  RA9_marcel  \
# 9        Andy Pettitte      145  4.018068       97.7    3.909177
# 10      Anibal Sanchez      197  4.039846      177.7    4.137848
# 14       Bartolo Colon      135  4.322962      151.0    4.214071
# 21    Brandon McCarthy      158  3.680507      132.7    3.843843
# 25         Brett Myers      178  4.518965       90.3    4.344740
# 63   Francisco Liriano      163  4.595189      147.7    5.106975
# 73       Hiroki Kuroda      198  3.952734      190.3    3.811176
# 74     Hisashi Iwakuma      179  4.028957      106.3    3.865621
# 92      Jeremy Guthrie      196  4.704080      169.0    4.812970
# 98         Joe Blanton      172  4.943639      157.3    5.041641
# 100       Joe Saunders      197  4.540743      168.7    4.420964
# 118      Kevin Correia      159  5.052530      158.0    4.900083
# 145        Paul Maholm      181  4.181404      170.3    4.312073
# 155      Ryan Dempster      190  4.246739      167.0    4.399186
# 163       Shaun Marcum      159  4.083402      142.3    4.061624
# 190       Zack Greinke      209  3.582505      183.7    4.105181
#
#      IP_rotochamp  RA9_rotochamp  IP_zips  RA9_zips   playerID  ...  bats  \
# 9             140       3.571616     90.3  4.453631  pettian01  ...     L
# 10            200       3.974512    185.0  4.606078  sanchan01  ...     R
# 14            120       4.410075    127.0  4.475409  colonba01  ...     R
# 21            130       4.301184    118.7  4.214071  mccarbr01  ...     R
# 25            150       4.181404    178.0  4.627856  myersbr01  ...     R
# 63            160       5.019863    154.7  4.050735  liriafr01  ...     L
# 73            180       3.647839    186.0  4.638745  kurodhi01  ...     R
# 74            160       3.985401    128.3  4.203182  iwakuhi01  ...     R
# 92            195       4.769414    163.7  4.791192  guthrje01  ...     R
# 98            170       4.497187    130.3  4.889194  blantjo01  ...     R
# 100           200       4.366518    164.7  4.704080  saundjo01  ...     L
# 118           150       5.030752    135.0  5.880099  correke01  ...     R
# 145           170       4.268517    168.0  4.377407  maholpa01  ...     L
# 155           200       4.366518    163.0  4.867416  dempsry01  ...     R
# 163           155       4.235849    161.7  3.756730  marcush01  ...     R
# 190           200       4.072513    203.3  3.375613  greinza01  ...     R
#
#      throws       debut finalGame   retroID    bbrefID  deathDate   birthDate  \
# 9         L  1995-04-29       NaN  petta001  pettian01        NaN  1972-06-15
# 10        R  2006-06-25       NaN  sanca004  sanchan01        NaN  1984-02-27
# 14        R  1997-04-04       NaN  colob001  colonba01        NaN  1973-05-24
# 21        R  2005-05-22       NaN  mccab001  mccarbr01        NaN  1983-07-07
# 25        R  2002-07-24       NaN  myerb001  myersbr01        NaN  1980-08-17
# 63        L  2005-09-05       NaN  lirif001  liriafr01        NaN  1983-10-26
# 73        R  2008-04-04       NaN  kuroh001  kurodhi01        NaN  1975-02-10
# 74        R  2012-04-20       NaN  iwakh001  iwakuhi01        NaN  1981-04-12
# 92        R  2004-08-28       NaN  guthj001  guthrje01        NaN  1979-04-08
# 98        R  2004-09-21       NaN  blanj001  blantjo01        NaN  1980-12-11
# 100       L  2005-08-16       NaN  saunj001  saundjo01        NaN  1981-06-16
# 118       R  2003-07-10       NaN  corrk001  correke01        NaN  1980-08-24
# 145       L  2005-08-30       NaN  mahop002  maholpa01        NaN  1982-06-25
# 155       R  1998-05-23       NaN  dempr002  dempsry01        NaN  1977-05-03
# 163       R  2005-09-06       NaN  marcs001  marcush01        NaN  1981-12-14
# 190       R  2004-05-22       NaN  greiz001  greinza01        NaN  1983-10-21
#
#      IP  RA9
# 9   NaN  NaN
# 10  NaN  NaN
# 14  NaN  NaN
# 21  NaN  NaN
# 25  NaN  NaN
# 63  NaN  NaN
# 73  NaN  NaN
# 74  NaN  NaN
# 92  NaN  NaN
# 98  NaN  NaN
# 100 NaN  NaN
# 118 NaN  NaN
# 145 NaN  NaN
# 155 NaN  NaN
# 163 NaN  NaN
# 190 NaN  NaN
#
# [16 rows x 66 columns]

# %%
free_agent_indices = test_df["NAME"].isin(free_agents)

# %%
free_agent_indices
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 186    False
# 187    False
# 188    False
# 189    False
# 190     True
# Name: NAME, Length: 191, dtype: bool

# %% [markdown]
# The following code will help you more easily read out your predictions for the individual pitchers in order to use the predictions in your decision. Note that until you have the variables `IP_pred_2013` and `RA9_pred_2013`, you will get an error if you try to run the below cell.

# %%
pd.DataFrame({'Name': test_df[free_agent_indices]["NAME"], 
              'Prediction IP 2013': IP_pred_2013[free_agent_indices], 
              'Prediction RA9 2013': RA9_pred_2013[free_agent_indices]}).set_index('Name')
# Out:
#                    Prediction IP 2013  Prediction RA9 2013
# Name
# Andy Pettitte               106.61444             4.040055
# Anibal Sanchez              160.48760             4.276249
# Bartolo Colon               110.53750             4.721084
# Brandon McCarthy            121.14176             4.441475
# Brett Myers                 141.82060             4.612142
# Francisco Liriano           132.58956             5.304586
# Hiroki Kuroda               161.40400             4.025919
# Hisashi Iwakuma             134.13704             4.383073
# Jeremy Guthrie              155.20056             5.031116
# Joe Blanton                 133.86924             4.919347
# Joe Saunders                156.08336             4.725892
# Kevin Correia               126.89070             5.111730
# Paul Maholm                 146.90720             4.580223
# Ryan Dempster               151.70930             4.560549
# Shaun Marcum                131.20426             4.667186
# Zack Greinke                171.10364             4.419656

# %% [markdown]
# # Write Out Predictions

# %%
predictions_df = pd.concat([test_df['NAME'], IP_pred_2013.rename('IP')], axis=1)

# %%
predictions_df.to_csv("IP_predictions_2013.csv", index=False)

# %% [markdown]
# In class, you will receive a realizations data set. Assuming that you have `IP_pred_2013` and `RA9_pred_2013` calculated from work above, running the below code will show your accuracy.

# %%
test_real_df = pd.read_csv("../Shared Data (Read Only)/Sabermetrics_SPF/test_saber_realization.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_74/2267638415.py in <module>
# ----> 1 test_real_df = pd.read_csv("../Shared Data (Read Only)/Sabermetrics_SPF/test_saber_realization.csv")
#
# /opt/conda/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# /opt/conda/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Shared Data (Read Only)/Sabermetrics_SPF/test_saber_realization.csv'

# %%
print("Your IP prediction performance was:")
accuracy(test_real_df["IP"], IP_pred_2013)

# %%
print("Your RA9 prediction performance was:")
accuracy(test_real_df["RA9"], RA9_pred_2013)
